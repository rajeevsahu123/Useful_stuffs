# %% [markdown]
# # How to download OHLCV data from yahoo using pandas-datareader
# for more information [Pandas-datareader](http://pandas-datareader.readthedocs.io/en/latest/remote_data.html)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline

from pandas_datareader import data as pdr
import datetime

end = datetime.date.today()
begin=end-pd.DateOffset(365*5)

st=begin.strftime('%Y-%m-%d')
ed=end.strftime('%Y-%m-%d')

df = pdr.get_data_yahoo("AAPL",st,ed)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-12-27  73.362854  73.750000  72.094284  73.580002  66.545334  113780100
# 2012-12-28  72.898575  73.497147  72.588570  72.798569  65.838600   88569600
# 2012-12-31  72.932854  76.485718  72.714287  76.024284  68.755913  164873100
# 2013-01-02  79.117142  79.285713  77.375717  78.432854  70.934219  140129500
# 2013-01-03  78.268570  78.524284  77.285713  77.442856  70.038872   88241300

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-19  175.029999  175.389999  174.089996  174.539993  174.539993
# 2017-12-20  174.869995  175.419998  173.250000  174.350006  174.350006
# 2017-12-21  174.169998  176.020004  174.100006  175.009995  175.009995
# 2017-12-22  174.679993  175.419998  174.500000  175.009995  175.009995
# 2017-12-26  170.800003  171.470001  169.679993  170.570007  170.570007
#
#               Volume
# Date
# 2017-12-19  27436400
# 2017-12-20  23475600
# 2017-12-21  20949900
# 2017-12-22  16349400
# 2017-12-26  33043700

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    106.720814   107.600394   105.815384   106.732050   102.639405
# std      29.512681    29.632628    29.360858    29.531731    30.874945
# min      55.424286    57.085712    55.014286    55.790001    50.750210
# 25%      79.335716    80.020714    78.881428    79.361427    73.577049
# 50%     107.779999   108.790001   106.660004   107.730003   103.662239
# 75%     125.869999   126.720001   124.740002   125.675003   119.914017
# max     175.110001   177.199997   174.860001   176.419998   176.419998
#
#              Volume
# count  1.259000e+03
# mean   5.669318e+07
# std    3.747902e+07
# min    1.147590e+07
# 25%    3.059865e+07
# 50%    4.664540e+07
# 75%    7.067290e+07
# max    3.652131e+08

# %% [markdown]
# # Visualization incomplete working on it

# %%
fig = plt.figure(figsize=(10,8))
# Set the outer colour to white
fig.patch.set_facecolor('white') 

# Plot the equity curve
ax1 = fig.add_subplot(411, ylabel='Close')
df['Close'].plot(ax=ax1, color="blue", lw=2.)
plt.grid(True)

# Plot the returns
ax2 = fig.add_subplot(412, ylabel='Volume')
df['Volume'].plot(ax=ax2, color="black", lw=2.)
plt.grid(True)

ax3 = fig.add_subplot(413, ylabel='High')
df['High'].plot(ax=ax3, color="red", lw=2.)
plt.grid(True)

# Plot the returns
ax4 = fig.add_subplot(414, ylabel='Max draw down, %')
#df['Adj Close'].plot(ax=ax3, color="red", lw=2.)
ax4.fill_between(df.index, df['Adj Close'], 200, color='orange')
plt.grid(True)
