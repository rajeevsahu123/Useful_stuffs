# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import load_iris
import seaborn as sns

# %%
x = pd.DataFrame(load_iris().data, columns=load_iris().feature_names)

# %%
y = pd.DataFrame(load_iris().target, columns=['target'])

# %%
corr = pd.DataFrame(load_iris().data, columns=load_iris().feature_names).corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(6, 5))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(150, 275, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, ax=ax,square=True, center=0, robust=True, annot=True, linewidths=1.5)
